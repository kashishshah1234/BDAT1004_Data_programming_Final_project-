# %%
pip install dash
# Out:
# Requirement already satisfied: dash in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (2.16.1)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from dash) (2.2.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from dash) (2.2.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from dash) (5.20.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from dash) (7.1.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from dash) (4.9.0)
# Requirement already satisfied: requests in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from dash) (2.28.1)
# Requirement already satisfied: retrying in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from dash) (1.5.6)
# Requirement already satisfied: setuptools in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from dash) (67.8.0)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from plotly>=5.0.0->dash) (8.2.3)
# Requirement already satisfied: packaging in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from plotly>=5.0.0->dash) (22.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from Werkzeug<3.1->dash) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata->dash) (3.18.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from requests->dash) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from requests->dash) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from requests->dash) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from requests->dash) (2022.12.7)
# Requirement already satisfied: six>=1.7.0 in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from retrying->dash) (1.16.0)
# Requirement already satisfied: colorama in c:\users\kashi\appdata\local\programs\python\python311\lib\site-packages (from click>=8.0->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import pandas as pd

app = dash.Dash(__name__)

# Load your dataset
# For example, assuming your dataset is a CSV file named 'loan_data.csv' in the same directory
data = pd.read_csv('loan_data.csv')

# Define the layout of the application
app.layout = html.Div(
    style={'font-family': 'Arial, sans-serif', 'margin': '50px'},
    children=[
        html.H1('Dataset Display', style={'text-align': 'center'}),
        
        html.Div(
            style={'display': 'flex', 'justify-content': 'center', 'margin-bottom': '30px'},
            children=[
                dcc.Dropdown(
                    id='column-dropdown',
                    options=[{'label': col, 'value': col} for col in data.columns],
                    value=data.columns[0],  # Default value
                    style={'width': '300px'}
                ),
            ]
        ),
        
        html.Div(
            style={'display': 'flex', 'justify-content': 'space-between'},
            children=[
                dcc.Graph(
                    id='line-plot',
                    style={'width': '48%', 'margin-right': '10px'}
                ),
                
                dcc.Graph(
                    id='scatter-plot',
                    style={'width': '48%', 'margin-left': '10px'}
                )
            ]
        )
    ]
)

# Callback to update the line plot
@app.callback(
    Output('line-plot', 'figure'),
    [Input('column-dropdown', 'value')]
)
def update_line_plot(selected_column):
    return {
        'data': [{
            'x': data.index,
            'y': data[selected_column],
            'type': 'line',
            'name': selected_column
        }],
        'layout': {
            'title': f'Line Plot of {selected_column}',
            'xaxis': {'title': 'Index'},
            'yaxis': {'title': selected_column},
            'margin': {'l': 40, 'b': 40, 't': 40, 'r': 40},
            'height': 400
        }
    }

# Callback to update the scatter plot
@app.callback(
    Output('scatter-plot', 'figure'),
    [Input('column-dropdown', 'value')]
)
def update_scatter_plot(selected_column):
    return {
        'data': [{
            'x': data[selected_column],
            'y': data[data.columns[0]],  # For simplicity, using the first column for y-axis
            'mode': 'markers',
            'name': selected_column
        }],
        'layout': {
            'title': f'Scatter Plot of {selected_column} vs. {data.columns[0]}',
            'xaxis': {'title': selected_column},
            'yaxis': {'title': data.columns[0]},
            'margin': {'l': 40, 'b': 40, 't': 40, 'r': 40},
            'height': 400
        }
    }

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# C:\Users\kashi\AppData\Local\Temp\ipykernel_3624\4085207544.py:2: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\kashi\AppData\Local\Temp\ipykernel_3624\4085207544.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 93
#      76     return {
#      77         'data': [{
#      78             'x': data[selected_column],
#    (...)
#      89         }
#      90     }
#      92 if __name__ == '__main__':
# ---> 93     app.run_server(debug=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\dash\dash.py:2223, in Dash.run_server(self, *args, **kwargs)
#    2217 def run_server(self, *args, **kwargs):
#    2218     """`run_server` is a deprecated alias of `run` and may be removed in a
#    2219     future version. We recommend using `app.run` instead.
#    2220
#    2221     See `app.run` for usage information.
#    2222     """
# -> 2223     self.run(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\dash\dash.py:2114, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    2111             extra_files.append(path)
#    2113 if jupyter_dash.active:
# -> 2114     jupyter_dash.run_app(
#    2115         self,
#    2116         mode=jupyter_mode,
#    2117         width=jupyter_width,
#    2118         height=jupyter_height,
#    2119         host=host,
#    2120         port=port,
#    2121         server_url=jupyter_server_url,
#    2122     )
#    2123 else:
#    2124     self.server.run(host=host, port=port, debug=debug, **flask_run_options)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\dash\_jupyter.py:404, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     402     display(HTML(msg))
#     403 else:
# --> 404     raise final_error
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\dash\_jupyter.py:391, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     388         raise err
#     390 try:
# --> 391     wait_for_app()
#     393     if self.in_colab:
#     394         JupyterDash._display_in_colab(dashboard_url, port, mode, width, height)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\retrying.py:56, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      54 @six.wraps(f)
#      55 def wrapped_f(*args, **kw):
# ---> 56     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\retrying.py:266, in Retrying.call(self, fn, *args, **kwargs)
#     263 if self.stop(attempt_number, delay_since_first_attempt_ms):
#     264     if not self._wrap_exception and attempt.has_exception:
#     265         # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 266         raise attempt.get()
#     267     else:
#     268         raise RetryError(attempt)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\retrying.py:301, in Attempt.get(self, wrap_exception)
#     299         raise RetryError(self)
#     300     else:
# --> 301         six.reraise(self.value[0], self.value[1], self.value[2])
#     302 else:
#     303     return self.value
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\six.py:719, in reraise(tp, value, tb)
#     717     if value.__traceback__ is not tb:
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#     721     value = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\retrying.py:251, in Retrying.call(self, fn, *args, **kwargs)
#     248     self._before_attempts(attempt_number)
#     250 try:
# --> 251     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     252 except:
#     253     tb = sys.exc_info()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\dash\_jupyter.py:382, in JupyterDash.run_app.<locals>.wait_for_app()
#     380     if res != "Alive":
#     381         url = f"http://{host}:{port}"
# --> 382         raise OSError(
#     383             f"Address '{url}' already in use.\n"
#     384             "    Try passing a different port to run_server."
#     385         )
#     386 except requests.ConnectionError as err:
#     387     _get_error()
#
# OSError: Address 'http://127.0.0.1:8050' already in use.
#     Try passing a different port to run_server.

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import pandas as pd

app = dash.Dash(__name__)

# Load your dataset
# For example, assuming your dataset is a CSV file named 'loan_data.csv' in the same directory
data = pd.read_csv('loan_data.csv')

# Define the layout of the application
app.layout = html.Div([
    html.H1('Dataset Display'),
    
    # Dropdown to select columns
    dcc.Dropdown(
        id='column-dropdown',
        options=[{'label': col, 'value': col} for col in data.columns],
        value=data.columns[0]  # Default value
    ),
    
    # Line plot
    dcc.Graph(id='line-plot'),
    
    # Scatter plot
    dcc.Graph(id='scatter-plot')
])

# Callback to update the line plot
@app.callback(
    Output('line-plot', 'figure'),
    [Input('column-dropdown', 'value')]
)
def update_line_plot(selected_column):
    return {
        'data': [{
            'x': data.index,
            'y': data[selected_column],
            'type': 'line',
            'name': selected_column
        }],
        'layout': {
            'title': f'Line Plot of {selected_column}',
            'xaxis': {'title': 'Index'},
            'yaxis': {'title': selected_column}
        }
    }

# Callback to update the scatter plot
@app.callback(
    Output('scatter-plot', 'figure'),
    [Input('column-dropdown', 'value')]
)
def update_scatter_plot(selected_column):
    return {
        'data': [{
            'x': data[selected_column],
            'y': data[data.columns[0]],  # For simplicity, using the first column for y-axis
            'mode': 'markers',
            'name': selected_column
        }],
        'layout': {
            'title': f'Scatter Plot of {selected_column} vs. {data.columns[0]}',
            'xaxis': {'title': selected_column},
            'yaxis': {'title': data.columns[0]}
        }
    }

if __name__ == '__main__':
    app.run_server(debug=True, port=8051)  # Use port 8051 instead of 8050
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import dash_table
import pandas as pd

app = dash.Dash(__name__)

# Load your dataset
# For example, assuming your dataset is a CSV file named 'loan_data.csv' in the same directory
data = pd.read_csv('loan_data.csv')

# Define the layout of the application
app.layout = html.Div([
    html.H1('Dataset Display'),
    
    # Dropdown to select columns
    dcc.Dropdown(
        id='column-dropdown',
        options=[{'label': col, 'value': col} for col in data.columns],
        value=data.columns[0],  # Default value
        style={'width': '300px', 'margin-bottom': '20px'}
    ),
    
    # Line plot
    dcc.Graph(id='line-plot'),
    
    # Scatter plot
    dcc.Graph(id='scatter-plot'),
    
    # Table to display dataset
    dash_table.DataTable(
        id='datatable',
        columns=[{'name': col, 'id': col} for col in data.columns],
        data=data.to_dict('records'),
        style_table={'margin-top': '20px'}
    )
])

# Callback to update the line plot
@app.callback(
    Output('line-plot', 'figure'),
    [Input('column-dropdown', 'value')]
)
def update_line_plot(selected_column):
    return {
        'data': [{
            'x': data.index,
            'y': data[selected_column],
            'type': 'line',
            'name': selected_column
        }],
        'layout': {
            'title': f'Line Plot of {selected_column}',
            'xaxis': {'title': 'Index'},
            'yaxis': {'title': selected_column}
        }
    }

# Callback to update the scatter plot
@app.callback(
    Output('scatter-plot', 'figure'),
    [Input('column-dropdown', 'value')]
)
def update_scatter_plot(selected_column):
    return {
        'data': [{
            'x': data[selected_column],
            'y': data[data.columns[0]],  # For simplicity, using the first column for y-axis
            'mode': 'markers',
            'name': selected_column
        }],
        'layout': {
            'title': f'Scatter Plot of {selected_column} vs. {data.columns[0]}',
            'xaxis': {'title': selected_column},
            'yaxis': {'title': data.columns[0]}
        }
    }

if __name__ == '__main__':
    app.run_server(debug=True, port=8052)  # Use port 8052 instead of 8051
# Out:
# C:\Users\kashi\AppData\Local\Temp\ipykernel_3624\3109922220.py:5: UserWarning:
#
#
# The dash_table package is deprecated. Please replace
# `import dash_table` with `from dash import dash_table`
#
# Also, if you're using any of the table format helpers (e.g. Group), replace
# `from dash_table.Format import Group` with
# `from dash.dash_table.Format import Group`
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8052/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
